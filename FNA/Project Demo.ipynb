# %%
import numpy as np
from data import X_train, y_train, X_test, y_test
from sklearn.preprocessing import StandardScaler
from metrics import *
from NB import *
from NN import *
from KMeans import *

# %% [markdown]
# ### 1. Naive Bayes Classifier
# #### initialize, train and test

# %%
nb = NaiveBayes()
nb._init_(X_train, y_train)
nb_pred = nb.predict(X_test.values)

# %% [markdown]
# #### Naive Bayes Classification Performance:

# %%
print("Naive Bayes accuracy :  ", round(accuracy(y_test, nb_pred), 2))
print("Naive Bayes precision :  ", round(precision(y_test, nb_pred), 2))
print("Naive Bayes recall :  ", round(recall(y_test, nb_pred), 2))
print("Naive Bayes False Negative rate :  ", round(fn_rate(y_test, nb_pred), 2))
print("Naive Bayes F1 :  ", round(f1(y_test, nb_pred), 2))
# Out:
# Naive Bayes accuracy :   0.95
# Naive Bayes precision :   0.95
# Naive Bayes recall :   0.9
# Naive Bayes False Negative rate :   0.1
# Naive Bayes F1 :   0.93

# %% [markdown]
# ### 2. Multilayered Neural Network Classifier
# #### initialize, train and test

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train.values)
X_test = scaler.fit_transform(X_test.values)
input_nodes = X_train.shape[1]
hidden_nodes = 32
output_nodes = 2
    
nn = NeuralNetwork([input_nodes, hidden_nodes, output_nodes])

nn.train(
    X_train,
    y_train,
    X_test,
    y_test,
    batch_size=10,
    epochs=100,
    l_rate=0.2,
    )

pred_nn = nn.predict(X_test)
# Out:
# Epoch 1/100 => Train Accuracy: 97.628% - Train Loss: 0.384401 - Test Accuracy: 98.63% - Test Loss: 0.097254
# Epoch 2/100 => Train Accuracy: 98.008% - Train Loss: 0.100481 - Test Accuracy: 99.083% - Test Loss: 0.055823
# Epoch 3/100 => Train Accuracy: 98.59700000000001% - Train Loss: 0.07966 - Test Accuracy: 99.539% - Test Loss: 0.048708
# Epoch 4/100 => Train Accuracy: 98.795% - Train Loss: 0.068666 - Test Accuracy: 99.539% - Test Loss: 0.044879
# Epoch 5/100 => Train Accuracy: 98.795% - Train Loss: 0.061889 - Test Accuracy: 99.539% - Test Loss: 0.04352
# Epoch 6/100 => Train Accuracy: 99.2% - Train Loss: 0.056148 - Test Accuracy: 99.539% - Test Loss: 0.042848
# Epoch 7/100 => Train Accuracy: 99.002% - Train Loss: 0.051649 - Test Accuracy: 99.074% - Test Loss: 0.042483
# Epoch 8/100 => Train Accuracy: 99.002% - Train Loss: 0.047698 - Test Accuracy: 99.074% - Test Loss: 0.042463
# Epoch 9/100 => Train Accuracy: 99.203% - Train Loss: 0.044446 - Test Accuracy: 99.074% - Test Loss: 0.042364
# Epoch 10/100 => Train Accuracy: 99.203% - Train Loss: 0.04113 - Test Accuracy: 99.074% - Test Loss: 0.042583
# Epoch 11/100 => Train Accuracy: 99.203% - Train Loss: 0.038669 - Test Accuracy: 99.074% - Test Loss: 0.042466
# Epoch 12/100 => Train Accuracy: 99.203% - Train Loss: 0.0362 - Test Accuracy: 99.074% - Test Loss: 0.042173
# Epoch 13/100 => Train Accuracy: 99.203% - Train Loss: 0.033468 - Test Accuracy: 99.074% - Test Loss: 0.042852
# Epoch 14/100 => Train Accuracy: 99.203% - Train Loss: 0.031799 - Test Accuracy: 99.074% - Test Loss: 0.04287
# Epoch 15/100 => Train Accuracy: 99.203% - Train Loss: 0.029512 - Test Accuracy: 99.074% - Test Loss: 0.043733
# Epoch 16/100 => Train Accuracy: 99.203% - Train Loss: 0.028136 - Test Accuracy: 99.074% - Test Loss: 0.043783
# Epoch 17/100 => Train Accuracy: 99.401% - Train Loss: 0.026362 - Test Accuracy: 99.074% - Test Loss: 0.044686
# Epoch 18/100 => Train Accuracy: 99.6% - Train Loss: 0.025103 - Test Accuracy: 99.074% - Test Loss: 0.044096
# Epoch 19/100 => Train Accuracy: 99.6% - Train Loss: 0.022933 - Test Accuracy: 99.074% - Test Loss: 0.044921
# Epoch 20/100 => Train Accuracy: 99.6% - Train Loss: 0.021705 - Test Accuracy: 99.074% - Test Loss: 0.044694
# Epoch 21/100 => Train Accuracy: 99.6% - Train Loss: 0.020285 - Test Accuracy: 99.074% - Test Loss: 0.045396
# Epoch 22/100 => Train Accuracy: 99.6% - Train Loss: 0.019573 - Test Accuracy: 99.074% - Test Loss: 0.045941
# Epoch 23/100 => Train Accuracy: 99.6% - Train Loss: 0.018359 - Test Accuracy: 99.074% - Test Loss: 0.046501
# Epoch 24/100 => Train Accuracy: 99.6% - Train Loss: 0.01744 - Test Accuracy: 99.074% - Test Loss: 0.047804
# Epoch 25/100 => Train Accuracy: 99.6% - Train Loss: 0.016729 - Test Accuracy: 99.074% - Test Loss: 0.047962
# Epoch 26/100 => Train Accuracy: 99.6% - Train Loss: 0.016333 - Test Accuracy: 98.605% - Test Loss: 0.051977
# Epoch 27/100 => Train Accuracy: 99.6% - Train Loss: 0.014905 - Test Accuracy: 99.074% - Test Loss: 0.05017
# Epoch 28/100 => Train Accuracy: 99.8% - Train Loss: 0.014391 - Test Accuracy: 99.074% - Test Loss: 0.050497
# Epoch 29/100 => Train Accuracy: 99.8% - Train Loss: 0.013973 - Test Accuracy: 98.605% - Test Loss: 0.05595
# Epoch 30/100 => Train Accuracy: 99.8% - Train Loss: 0.013284 - Test Accuracy: 98.605% - Test Loss: 0.053816
# Epoch 31/100 => Train Accuracy: 99.8% - Train Loss: 0.012517 - Test Accuracy: 98.605% - Test Loss: 0.057098
# Epoch 32/100 => Train Accuracy: 99.8% - Train Loss: 0.011909 - Test Accuracy: 98.605% - Test Loss: 0.054596
# Epoch 33/100 => Train Accuracy: 99.8% - Train Loss: 0.011493 - Test Accuracy: 98.605% - Test Loss: 0.059669
# Epoch 34/100 => Train Accuracy: 99.8% - Train Loss: 0.010872 - Test Accuracy: 98.605% - Test Loss: 0.059252
# Epoch 35/100 => Train Accuracy: 99.8% - Train Loss: 0.010369 - Test Accuracy: 98.605% - Test Loss: 0.059914
# Epoch 36/100 => Train Accuracy: 99.8% - Train Loss: 0.009861 - Test Accuracy: 98.605% - Test Loss: 0.058924
# Epoch 37/100 => Train Accuracy: 99.8% - Train Loss: 0.009783 - Test Accuracy: 98.605% - Test Loss: 0.063809
# Epoch 38/100 => Train Accuracy: 99.8% - Train Loss: 0.009096 - Test Accuracy: 98.605% - Test Loss: 0.062375
# Epoch 39/100 => Train Accuracy: 99.8% - Train Loss: 0.008641 - Test Accuracy: 98.605% - Test Loss: 0.064559
# Epoch 40/100 => Train Accuracy: 99.8% - Train Loss: 0.008382 - Test Accuracy: 98.605% - Test Loss: 0.064342
# Epoch 41/100 => Train Accuracy: 99.8% - Train Loss: 0.008082 - Test Accuracy: 98.605% - Test Loss: 0.06492
# Epoch 42/100 => Train Accuracy: 99.8% - Train Loss: 0.007656 - Test Accuracy: 98.605% - Test Loss: 0.068075
# Epoch 43/100 => Train Accuracy: 100.0% - Train Loss: 0.007318 - Test Accuracy: 98.605% - Test Loss: 0.068672
# Epoch 44/100 => Train Accuracy: 100.0% - Train Loss: 0.007063 - Test Accuracy: 98.605% - Test Loss: 0.068802
# Epoch 45/100 => Train Accuracy: 100.0% - Train Loss: 0.006768 - Test Accuracy: 98.605% - Test Loss: 0.072435
# Epoch 46/100 => Train Accuracy: 100.0% - Train Loss: 0.006389 - Test Accuracy: 98.605% - Test Loss: 0.070456
# Epoch 47/100 => Train Accuracy: 100.0% - Train Loss: 0.006218 - Test Accuracy: 98.605% - Test Loss: 0.072363
# Epoch 48/100 => Train Accuracy: 100.0% - Train Loss: 0.00594 - Test Accuracy: 98.605% - Test Loss: 0.071827
# Epoch 49/100 => Train Accuracy: 100.0% - Train Loss: 0.005683 - Test Accuracy: 98.605% - Test Loss: 0.075042
# Epoch 50/100 => Train Accuracy: 100.0% - Train Loss: 0.005409 - Test Accuracy: 98.605% - Test Loss: 0.075852
# Epoch 51/100 => Train Accuracy: 100.0% - Train Loss: 0.005202 - Test Accuracy: 98.605% - Test Loss: 0.07709
# Epoch 52/100 => Train Accuracy: 100.0% - Train Loss: 0.005021 - Test Accuracy: 98.605% - Test Loss: 0.076796
# Epoch 53/100 => Train Accuracy: 100.0% - Train Loss: 0.00489 - Test Accuracy: 98.605% - Test Loss: 0.078426
# Epoch 54/100 => Train Accuracy: 100.0% - Train Loss: 0.004659 - Test Accuracy: 98.605% - Test Loss: 0.07934
# Epoch 55/100 => Train Accuracy: 100.0% - Train Loss: 0.004394 - Test Accuracy: 98.605% - Test Loss: 0.079433
# Epoch 56/100 => Train Accuracy: 100.0% - Train Loss: 0.004245 - Test Accuracy: 98.605% - Test Loss: 0.080968
# Epoch 57/100 => Train Accuracy: 100.0% - Train Loss: 0.004202 - Test Accuracy: 98.605% - Test Loss: 0.08143
# Epoch 58/100 => Train Accuracy: 100.0% - Train Loss: 0.004018 - Test Accuracy: 98.605% - Test Loss: 0.083826
# Epoch 59/100 => Train Accuracy: 100.0% - Train Loss: 0.003815 - Test Accuracy: 98.605% - Test Loss: 0.082806
# Epoch 60/100 => Train Accuracy: 100.0% - Train Loss: 0.003731 - Test Accuracy: 98.605% - Test Loss: 0.082891
# Epoch 61/100 => Train Accuracy: 100.0% - Train Loss: 0.003599 - Test Accuracy: 98.605% - Test Loss: 0.08431
# Epoch 62/100 => Train Accuracy: 100.0% - Train Loss: 0.003459 - Test Accuracy: 98.605% - Test Loss: 0.086163
# Epoch 63/100 => Train Accuracy: 100.0% - Train Loss: 0.00337 - Test Accuracy: 98.605% - Test Loss: 0.086901
# Epoch 64/100 => Train Accuracy: 100.0% - Train Loss: 0.003276 - Test Accuracy: 98.605% - Test Loss: 0.088702
# Epoch 65/100 => Train Accuracy: 100.0% - Train Loss: 0.003163 - Test Accuracy: 98.605% - Test Loss: 0.086351
# Epoch 66/100 => Train Accuracy: 100.0% - Train Loss: 0.00306 - Test Accuracy: 98.605% - Test Loss: 0.087978
# Epoch 67/100 => Train Accuracy: 100.0% - Train Loss: 0.002989 - Test Accuracy: 98.605% - Test Loss: 0.08976
# Epoch 68/100 => Train Accuracy: 100.0% - Train Loss: 0.002891 - Test Accuracy: 98.605% - Test Loss: 0.090402
# Epoch 69/100 => Train Accuracy: 100.0% - Train Loss: 0.002836 - Test Accuracy: 98.605% - Test Loss: 0.091297
# Epoch 70/100 => Train Accuracy: 100.0% - Train Loss: 0.002741 - Test Accuracy: 98.605% - Test Loss: 0.092018
# Epoch 71/100 => Train Accuracy: 100.0% - Train Loss: 0.002659 - Test Accuracy: 98.605% - Test Loss: 0.092269
# Epoch 72/100 => Train Accuracy: 100.0% - Train Loss: 0.002617 - Test Accuracy: 98.605% - Test Loss: 0.094241
# Epoch 73/100 => Train Accuracy: 100.0% - Train Loss: 0.002533 - Test Accuracy: 98.605% - Test Loss: 0.094327
# Epoch 74/100 => Train Accuracy: 100.0% - Train Loss: 0.002467 - Test Accuracy: 98.605% - Test Loss: 0.093719
# Epoch 75/100 => Train Accuracy: 100.0% - Train Loss: 0.002414 - Test Accuracy: 98.605% - Test Loss: 0.095135
# Epoch 76/100 => Train Accuracy: 100.0% - Train Loss: 0.00234 - Test Accuracy: 98.605% - Test Loss: 0.09707
# Epoch 77/100 => Train Accuracy: 100.0% - Train Loss: 0.002298 - Test Accuracy: 98.605% - Test Loss: 0.095405
# Epoch 78/100 => Train Accuracy: 100.0% - Train Loss: 0.002223 - Test Accuracy: 98.605% - Test Loss: 0.096474
# Epoch 79/100 => Train Accuracy: 100.0% - Train Loss: 0.00218 - Test Accuracy: 98.605% - Test Loss: 0.097657
# Epoch 80/100 => Train Accuracy: 100.0% - Train Loss: 0.002148 - Test Accuracy: 98.605% - Test Loss: 0.098123
# Epoch 81/100 => Train Accuracy: 100.0% - Train Loss: 0.0021 - Test Accuracy: 98.605% - Test Loss: 0.099157
# Epoch 82/100 => Train Accuracy: 100.0% - Train Loss: 0.002046 - Test Accuracy: 98.605% - Test Loss: 0.099602
# Epoch 83/100 => Train Accuracy: 100.0% - Train Loss: 0.002018 - Test Accuracy: 98.605% - Test Loss: 0.100737
# Epoch 84/100 => Train Accuracy: 100.0% - Train Loss: 0.001969 - Test Accuracy: 98.605% - Test Loss: 0.101659
# Epoch 85/100 => Train Accuracy: 100.0% - Train Loss: 0.001929 - Test Accuracy: 98.605% - Test Loss: 0.101486
# Epoch 86/100 => Train Accuracy: 100.0% - Train Loss: 0.001883 - Test Accuracy: 98.605% - Test Loss: 0.102035
# Epoch 87/100 => Train Accuracy: 100.0% - Train Loss: 0.001847 - Test Accuracy: 98.605% - Test Loss: 0.102603
# Epoch 88/100 => Train Accuracy: 100.0% - Train Loss: 0.001821 - Test Accuracy: 98.605% - Test Loss: 0.103821
# Epoch 89/100 => Train Accuracy: 100.0% - Train Loss: 0.001778 - Test Accuracy: 98.605% - Test Loss: 0.104314
# Epoch 90/100 => Train Accuracy: 100.0% - Train Loss: 0.001749 - Test Accuracy: 98.605% - Test Loss: 0.104108
# Epoch 91/100 => Train Accuracy: 100.0% - Train Loss: 0.001708 - Test Accuracy: 98.605% - Test Loss: 0.104814
# Epoch 92/100 => Train Accuracy: 100.0% - Train Loss: 0.001679 - Test Accuracy: 98.605% - Test Loss: 0.104744
# Epoch 93/100 => Train Accuracy: 100.0% - Train Loss: 0.001647 - Test Accuracy: 98.605% - Test Loss: 0.106571
# Epoch 94/100 => Train Accuracy: 100.0% - Train Loss: 0.001624 - Test Accuracy: 98.605% - Test Loss: 0.106545
# Epoch 95/100 => Train Accuracy: 100.0% - Train Loss: 0.001595 - Test Accuracy: 98.131% - Test Loss: 0.107686
# Epoch 96/100 => Train Accuracy: 100.0% - Train Loss: 0.001566 - Test Accuracy: 98.605% - Test Loss: 0.107724
# Epoch 97/100 => Train Accuracy: 100.0% - Train Loss: 0.001536 - Test Accuracy: 98.131% - Test Loss: 0.108549
# Epoch 98/100 => Train Accuracy: 100.0% - Train Loss: 0.001513 - Test Accuracy: 98.131% - Test Loss: 0.10853
# Epoch 99/100 => Train Accuracy: 100.0% - Train Loss: 0.001478 - Test Accuracy: 98.131% - Test Loss: 0.108373
# Epoch 100/100 => Train Accuracy: 100.0% - Train Loss: 0.001448 - Test Accuracy: 98.605% - Test Loss: 0.10965

# %% [markdown]
# #### Multilayered Neural Network Classification Performance:

# %%
print("Multilayered Neural Network accuracy :  ", round(accuracy(y_test, pred_nn), 2))
print("Multilayered Neural Network precision :  ", round(precision(y_test, pred_nn), 2))
print("Multilayered Neural Network recall :  ", round(recall(y_test, pred_nn), 2))
print("Multilayered Neural Network False Negative rate :  ", round(fn_rate(y_test, pred_nn), 2))
print("Multilayered Neural Network F1 :  ", round(f1(y_test, pred_nn), 2))
# Out:
# Multilayered Neural Network accuracy :   0.99
# Multilayered Neural Network precision :   0.98
# Multilayered Neural Network recall :   0.98
# Multilayered Neural Network False Negative rate :   0.02
# Multilayered Neural Network F1 :   0.98

# %% [markdown]
# ### 3. K-Means Classifier
# #### initialize, train and test

# %%
kmeans_verbose = KMeans()
clusters, centroids, training_score = kmeans_verbose.fit(DATA.X_train, DATA.y_train, k=2, n_runs=3, verbose=True)
# Out:
# RUN 1
# initial centroids
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 492        18.01         20.56           118.4     1007.0           0.1001
# 451        19.59         25.00           127.7     1191.0           0.1032
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 492           0.12890          0.1170              0.07762         0.2116
# 451           0.09871          0.1655              0.09063         0.1663
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 492                 0.06077  ...         21.53          26.06
# 451                 0.05391  ...         21.44          30.96
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 492            143.4      1426.0            0.1309             0.2327
# 451            139.8      1421.0            0.1528             0.1845
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 492           0.2544                0.1489          0.3251
# 451           0.3977                0.1466          0.2293
#
#      fractal_dimension_worst
# 492                  0.07625
# 451                  0.06091
#
# [2 rows x 30 columns]
# Final centroids
#             radius_mean  texture_mean  perimeter_mean    area_mean  \
# cluster id
# 0.0           13.175300     18.771988       85.383343   552.887032
# 1.0           20.985294     21.793529      139.019608  1387.000000
#
#             smoothness_mean  compactness_mean  concavity_mean  \
# cluster id
# 0.0                0.095324          0.096759        0.072758
# 1.0                0.100302          0.147828        0.192259
#
#             concave points_mean  symmetry_mean  fractal_dimension_mean  ...  \
# cluster id                                                              ...
# 0.0                    0.039415       0.178942                0.063187  ...
# 1.0                    0.109844       0.189604                0.059105  ...
#
#             texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# cluster id
# 0.0             24.999395        98.206369   715.877810          0.130930
# 1.0             28.949412       169.670588  2011.098039          0.137498
#
#             compactness_worst  concavity_worst  concave points_worst  \
# cluster id
# 0.0                  0.236107         0.241494              0.101408
# 1.0                  0.337392         0.452229              0.198420
#
#             symmetry_worst  fractal_dimension_worst  centroid distance
# cluster id
# 0.0               0.286351                 0.083701         869.165529
# 1.0               0.301559                 0.082424         665.945560
#
# [2 rows x 31 columns]
# f1score: 0.51
#
#
# RUN 2
# initial centroids
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 370        16.35         23.29           109.0      840.4          0.09742
# 262        17.29         22.13           114.4      947.8          0.08999
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 370            0.1497         0.18110              0.08773         0.2175
# 262            0.1273         0.09697              0.07507         0.2108
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 370                 0.06218  ...         19.38          31.03
# 262                 0.05464  ...         20.39          27.24
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 370            129.3      1165.0            0.1415             0.4665
# 262            137.9      1295.0            0.1134             0.2867
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 370           0.7087                0.2248          0.4824
# 262           0.2298                0.1528          0.3067
#
#      fractal_dimension_worst
# 370                  0.09614
# 262                  0.07484
#
# [2 rows x 30 columns]
# Final centroids
#             radius_mean  texture_mean  perimeter_mean    area_mean  \
# cluster id
# 0.0            12.67923     18.536613       81.995272   506.167412
# 1.0            19.68800     21.451647      130.041176  1225.392941
#
#             smoothness_mean  compactness_mean  concavity_mean  \
# cluster id
# 0.0                0.094759          0.092829        0.064891
# 1.0                0.100390          0.141873        0.173428
#
#             concave points_mean  symmetry_mean  fractal_dimension_mean  ...  \
# cluster id                                                              ...
# 0.0                    0.034546       0.177556                0.063463  ...
# 1.0                    0.099602       0.190445                0.059721  ...
#
#             texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# cluster id
# 0.0             24.663674        93.208658   634.902875          0.129829
# 1.0             28.605647       159.488235  1791.188235          0.138928
#
#             compactness_worst  concavity_worst  concave points_worst  \
# cluster id
# 0.0                  0.227725         0.224539              0.093739
# 1.0                  0.327745         0.430366              0.187854
#
#             symmetry_worst  fractal_dimension_worst  centroid distance
# cluster id
# 0.0               0.283291                 0.083512         634.964107
# 1.0               0.306744                 0.083629         607.773271
#
# [2 rows x 31 columns]
# f1score: 0.7199834105204947
#
#
# RUN 3
# initial centroids
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 149        13.74         17.91           88.12      585.0          0.07944
# 372        21.37         15.10          141.30     1386.0          0.10010
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 149           0.06376         0.02881              0.01329         0.1473
# 372           0.15150         0.19320              0.12550         0.1973
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 149                 0.05580  ...         15.34          22.46
# 372                 0.06183  ...         22.69          21.84
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 149            97.19       725.9           0.09711             0.1824
# 372           152.10      1535.0           0.11920             0.2840
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 149           0.1564               0.06019           0.235
# 372           0.4024               0.19660           0.273
#
#      fractal_dimension_worst
# 149                  0.07014
# 372                  0.08666
#
# [2 rows x 30 columns]
# Final centroids
#             radius_mean  texture_mean  perimeter_mean    area_mean  \
# cluster id
# 0.0           12.674374     18.535687       81.971949   505.657508
# 1.0           19.705882     21.455059      130.127059  1227.270588
#
#             smoothness_mean  compactness_mean  concavity_mean  \
# cluster id
# 0.0                0.094850          0.093095        0.065273
# 1.0                0.100057          0.140894        0.172021
#
#             concave points_mean  symmetry_mean  fractal_dimension_mean  ...  \
# cluster id                                                              ...
# 0.0                    0.034665       0.177525                0.063512  ...
# 1.0                    0.099164       0.190559                0.059542  ...
#
#             texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# cluster id
# 0.0             24.677604        93.247316   635.378914          0.130011
# 1.0             28.554353       159.345882  1789.435294          0.138257
#
#             compactness_worst  concavity_worst  concave points_worst  \
# cluster id
# 0.0                   0.22850         0.225696              0.094066
# 1.0                   0.32489         0.426106              0.186648
#
#             symmetry_worst  fractal_dimension_worst  centroid distance
# cluster id
# 0.0               0.283263                 0.083631         248.862642
# 1.0               0.306847                 0.083192         543.710968
#
# [2 rows x 31 columns]
# f1score: 0.7199834105204947

# %%
kmeans = KMeans()
clusters, centroids, training_score = kmeans.fit(DATA.X_train, DATA.y_train, k=2, n_runs=10, verbose=False)

# inversion check
kmeans_pred = kmeans.predict(DATA.X_test)
inverted_kmeans_pred = [0 if y == 1 else 1 for y in kmeans_pred]
kmeans_f1score = round(f1(y_test, kmeans_pred), 2)
kmeans_inverted_f1score = round(f1(y_test, inverted_kmeans_pred), 2)
pred_km = inverted_kmeans_pred if kmeans_inverted_f1score > kmeans_f1score else kmeans_pred

# %% [markdown]
# #### K-Means Classification Performance:

# %%
print("K-Means accuracy :  ", round(accuracy(y_test, pred_km), 2))
print("K-Means precision :  ", round(precision(y_test, pred_km), 2))
print("K-Means recall :  ", round(recall(y_test, pred_km), 2))
print("K-Means False negative rate :  ", round(fn_rate(y_test, pred_km), 2))
print("K-Means F1 :  ", round(f1(y_test, pred_km), 2))
# Out:
# K-Means accuracy :   0.94
# K-Means precision :   1.0
# K-Means recall :   0.76
# K-Means False negative rate :   0.24
# K-Means F1 :   0.86
